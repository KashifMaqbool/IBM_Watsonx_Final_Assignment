# %% [markdown]
# # My Jupyter Notebook on IBM watsonx.ai

# %% [markdown]
# **My name is Kashif Maqbool and I am a Computer Scientist.**

# %% [markdown]
# *I am interested in Data Science because I am interested in Business and I love to work with data.*

# %% [markdown]
# ### This code is written in python.

# %%
1+1
# Out:
# 2

# %% [markdown]
# # This Table represents the Crops Items
# Crops|Quantitiy(Kg)|Price(In Rupee)
# ------|-------------|---------------
# Wheat|2|500
# Rice|1|200
# Barley|3|1000
# Potatoe|2|400
#
# # This section shows the link in markdown cell
# [Link for Youtube] (https://www.youtube.com/)
#
#
# # This section shows the Images in markdown cell
# Flower_Image: ![Images of the Flower](https://www.pexels.com/photo/close-photography-of-red-and-pink-rose-56866/)
